# %%
import requests
import time
import json

# API configuration
TAGS = ["nlp", "nltk", "spacy", "transformers", "text-classification"]
SITE = "stackoverflow"
PAGE_SIZE = 100
MAX_PAGES = 200
OUTPUT_FILE = "stackoverflow_nlp_posts_with_answers.json"
API_KEY = "rl_ndUUpkDFr5NnfioGSSC4VfKu4"
TARGET_COUNT = 20000

all_questions = []
valid_question_count = 0

# Loop through tags and paginated questions
for tag in TAGS:
    if valid_question_count >= TARGET_COUNT:
        break

    for page in range(1, MAX_PAGES + 1):
        if valid_question_count >= TARGET_COUNT:
            break

        print(f"Fetching page {page} for tag [{tag}]...")

        url = "https://api.stackexchange.com/2.3/questions"
        params = {
            "page": page,
            "pagesize": PAGE_SIZE,
            "order": "desc",
            "sort": "creation",
            "tagged": tag,
            "site": SITE,
            "filter": "withbody",
            "key": API_KEY
        }

        response = requests.get(url, params=params)
        if response.status_code != 200:
            print(f"Error {response.status_code}: {response.text}")
            break

        try:
            data = response.json()
        except ValueError:
            print("Invalid JSON response. Skipping this page.")
            continue

        if "items" not in data or not data["items"]:
            print(f"No items found for tag [{tag}], page {page}")
            break

        # Filter questions that have accepted answers
        questions_with_answers = [
            item for item in data["items"]
            if item.get("accepted_answer_id")
        ]

        # Fetch bodies of accepted answers in batches
        accepted_ids = [str(item["accepted_answer_id"]) for item in questions_with_answers]
        id_batches = [accepted_ids[i:i+100] for i in range(0, len(accepted_ids), 100)]

        accepted_answers = {}
        for batch in id_batches:
            ids_str = ";".join(batch)
            ans_url = f"https://api.stackexchange.com/2.3/answers/{ids_str}"
            ans_params = {
                "site": SITE,
                "filter": "withbody",
                "key": API_KEY
            }
            ans_response = requests.get(ans_url, params=ans_params)
            if ans_response.status_code == 200:
                try:
                    ans_data = ans_response.json()
                    for ans in ans_data.get("items", []):
                        accepted_answers[ans["answer_id"]] = ans.get("body")
                except ValueError:
                    continue

            time.sleep(0.5)  

        # Merge question and its accepted answer into the dataset
        for item in questions_with_answers:
            if valid_question_count >= TARGET_COUNT:
                break

            aid = item["accepted_answer_id"]
            abody = accepted_answers.get(aid)

            if abody:
                question_data = {
                    "question_id": item.get("question_id"),
                    "title": item.get("title"),
                    "body": item.get("body"),
                    "tags": item.get("tags"),
                    "accepted_answer_id": aid,
                    "accepted_answer_body": abody,
                    "score": item.get("score")
                }
                all_questions.append(question_data)
                valid_question_count += 1

        print(f" Total collected so far: {valid_question_count}")
        time.sleep(0.5)

# Save all collected data to a JSON file
with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump(all_questions, f, indent=4)

print(f" Done! Saved {valid_question_count} valid Q&A posts to {OUTPUT_FILE}")
# Out:
# Fetching page 1 for tag [nlp]...
#  Total collected so far: 18
# Fetching page 2 for tag [nlp]...
#  Total collected so far: 38
# Fetching page 3 for tag [nlp]...
#  Total collected so far: 57
# Fetching page 4 for tag [nlp]...
#  Total collected so far: 67
# Fetching page 5 for tag [nlp]...
#  Total collected so far: 79
# Fetching page 6 for tag [nlp]...
#  Total collected so far: 99
# Fetching page 7 for tag [nlp]...
#  Total collected so far: 125
# Fetching page 8 for tag [nlp]...
#  Total collected so far: 153
# Fetching page 9 for tag [nlp]...
#  Total collected so far: 175
# Fetching page 10 for tag [nlp]...
#  Total collected so far: 205
# Fetching page 11 for tag [nlp]...
#  Total collected so far: 223
# Fetching page 12 for tag [nlp]...
#  Total collected so far: 243
# Fetching page 13 for tag [nlp]...
#  Total collected so far: 273
# Fetching page 14 for tag [nlp]...
#  Total collected so far: 298
# Fetching page 15 for tag [nlp]...
#  Total collected so far: 328
# Fetching page 16 for tag [nlp]...
#  Total collected so far: 358
# Fetching page 17 for tag [nlp]...
#  Total collected so far: 383
# Fetching page 18 for tag [nlp]...
#  Total collected so far: 413
# Fetching page 19 for tag [nlp]...
#  Total collected so far: 442
# Fetching page 20 for tag [nlp]...
#  Total collected so far: 472
# Fetching page 21 for tag [nlp]...
#  Total collected so far: 502
# Fetching page 22 for tag [nlp]...
#  Total collected so far: 532
# Fetching page 23 for tag [nlp]...
#  Total collected so far: 562
# Fetching page 24 for tag [nlp]...
#  Total collected so far: 592
# Fetching page 25 for tag [nlp]...
#  Total collected so far: 622
# Fetching page 26 for tag [nlp]...
#  Total collected so far: 648
# Fetching page 27 for tag [nlp]...
#  Total collected so far: 678
# Fetching page 28 for tag [nlp]...
#  Total collected so far: 708
# Fetching page 29 for tag [nlp]...
#  Total collected so far: 738
# Fetching page 30 for tag [nlp]...
#  Total collected so far: 768
# Fetching page 31 for tag [nlp]...
#  Total collected so far: 798
# Fetching page 32 for tag [nlp]...
#  Total collected so far: 826
# Fetching page 33 for tag [nlp]...
#  Total collected so far: 856
# Fetching page 34 for tag [nlp]...
#  Total collected so far: 886
# Fetching page 35 for tag [nlp]...
#  Total collected so far: 916
# Fetching page 36 for tag [nlp]...
#  Total collected so far: 946
# Fetching page 37 for tag [nlp]...
#  Total collected so far: 976
# Fetching page 38 for tag [nlp]...
#  Total collected so far: 1006
# Fetching page 39 for tag [nlp]...
#  Total collected so far: 1036
# Fetching page 40 for tag [nlp]...
#  Total collected so far: 1066
# Fetching page 41 for tag [nlp]...
#  Total collected so far: 1096
# Fetching page 42 for tag [nlp]...
#  Total collected so far: 1126
# Fetching page 43 for tag [nlp]...
#  Total collected so far: 1156
# Fetching page 44 for tag [nlp]...
#  Total collected so far: 1185
# Fetching page 45 for tag [nlp]...
#  Total collected so far: 1214
# Fetching page 46 for tag [nlp]...
#  Total collected so far: 1244
# Fetching page 47 for tag [nlp]...
#  Total collected so far: 1274
# Fetching page 48 for tag [nlp]...
#  Total collected so far: 1304
# Fetching page 49 for tag [nlp]...
#  Total collected so far: 1334
# Fetching page 50 for tag [nlp]...
#  Total collected so far: 1364
# Fetching page 51 for tag [nlp]...
#  Total collected so far: 1394
# Fetching page 52 for tag [nlp]...
#  Total collected so far: 1424
# Fetching page 53 for tag [nlp]...
#  Total collected so far: 1454
# Fetching page 54 for tag [nlp]...
#  Total collected so far: 1484
# Fetching page 55 for tag [nlp]...
#  Total collected so far: 1514
# Fetching page 56 for tag [nlp]...
#  Total collected so far: 1544
# Fetching page 57 for tag [nlp]...
#  Total collected so far: 1574
# Fetching page 58 for tag [nlp]...
#  Total collected so far: 1604
# Fetching page 59 for tag [nlp]...
#  Total collected so far: 1634
# Fetching page 60 for tag [nlp]...
#  Total collected so far: 1664
# Fetching page 61 for tag [nlp]...
#  Total collected so far: 1694
# Fetching page 62 for tag [nlp]...
#  Total collected so far: 1724
# Fetching page 63 for tag [nlp]...
#  Total collected so far: 1754
# Fetching page 64 for tag [nlp]...
#  Total collected so far: 1784
# Fetching page 65 for tag [nlp]...
#  Total collected so far: 1814
# Fetching page 66 for tag [nlp]...
#  Total collected so far: 1844
# Fetching page 67 for tag [nlp]...
#  Total collected so far: 1874
# Fetching page 68 for tag [nlp]...
#  Total collected so far: 1904
# Fetching page 69 for tag [nlp]...
#  Total collected so far: 1934
# Fetching page 70 for tag [nlp]...
#  Total collected so far: 1964
# Fetching page 71 for tag [nlp]...
#  Total collected so far: 1994
# Fetching page 72 for tag [nlp]...
#  Total collected so far: 2024
# Fetching page 73 for tag [nlp]...
#  Total collected so far: 2054
# Fetching page 74 for tag [nlp]...
#  Total collected so far: 2084
# Fetching page 75 for tag [nlp]...
#  Total collected so far: 2114
# Fetching page 76 for tag [nlp]...
#  Total collected so far: 2144
# Fetching page 77 for tag [nlp]...
#  Total collected so far: 2174
# Fetching page 78 for tag [nlp]...
#  Total collected so far: 2204
# Fetching page 79 for tag [nlp]...
#  Total collected so far: 2234
# Fetching page 80 for tag [nlp]...
#  Total collected so far: 2264
# Fetching page 81 for tag [nlp]...
#  Total collected so far: 2294
# Fetching page 82 for tag [nlp]...
#  Total collected so far: 2324
# Fetching page 83 for tag [nlp]...
#  Total collected so far: 2354
# Fetching page 84 for tag [nlp]...
#  Total collected so far: 2384
# Fetching page 85 for tag [nlp]...
#  Total collected so far: 2414
# Fetching page 86 for tag [nlp]...
#  Total collected so far: 2444
# Fetching page 87 for tag [nlp]...
#  Total collected so far: 2474
# Fetching page 88 for tag [nlp]...
#  Total collected so far: 2503
# Fetching page 89 for tag [nlp]...
#  Total collected so far: 2533
# Fetching page 90 for tag [nlp]...
#  Total collected so far: 2563
# Fetching page 91 for tag [nlp]...
#  Total collected so far: 2593
# Fetching page 92 for tag [nlp]...
#  Total collected so far: 2623
# Fetching page 93 for tag [nlp]...
#  Total collected so far: 2653
# Fetching page 94 for tag [nlp]...
#  Total collected so far: 2683
# Fetching page 95 for tag [nlp]...
#  Total collected so far: 2713
# Fetching page 96 for tag [nlp]...
#  Total collected so far: 2743
# Fetching page 97 for tag [nlp]...
#  Total collected so far: 2773
# Fetching page 98 for tag [nlp]...
#  Total collected so far: 2803
# Fetching page 99 for tag [nlp]...
#  Total collected so far: 2833
# Fetching page 100 for tag [nlp]...
#  Total collected so far: 2863
# Fetching page 101 for tag [nlp]...
#  Total collected so far: 2893
# Fetching page 102 for tag [nlp]...
#  Total collected so far: 2923
# Fetching page 103 for tag [nlp]...
#  Total collected so far: 2953
# Fetching page 104 for tag [nlp]...
#  Total collected so far: 2983
# Fetching page 105 for tag [nlp]...
#  Total collected so far: 3013
# Fetching page 106 for tag [nlp]...
#  Total collected so far: 3043
# Fetching page 107 for tag [nlp]...
#  Total collected so far: 3073
# Fetching page 108 for tag [nlp]...
#  Total collected so far: 3103
# Fetching page 109 for tag [nlp]...
#  Total collected so far: 3133
# Fetching page 110 for tag [nlp]...
#  Total collected so far: 3163
# Fetching page 111 for tag [nlp]...
#  Total collected so far: 3193
# Fetching page 112 for tag [nlp]...
#  Total collected so far: 3223
# Fetching page 113 for tag [nlp]...
#  Total collected so far: 3253
# Fetching page 114 for tag [nlp]...
#  Total collected so far: 3283
# Fetching page 115 for tag [nlp]...
#  Total collected so far: 3313
# Fetching page 116 for tag [nlp]...
#  Total collected so far: 3343
# Fetching page 117 for tag [nlp]...
#  Total collected so far: 3373
# Fetching page 118 for tag [nlp]...
#  Total collected so far: 3403
# Fetching page 119 for tag [nlp]...
#  Total collected so far: 3433
# Fetching page 120 for tag [nlp]...
#  Total collected so far: 3463
# Fetching page 121 for tag [nlp]...
#  Total collected so far: 3493
# Fetching page 122 for tag [nlp]...
#  Total collected so far: 3523
# Fetching page 123 for tag [nlp]...
#  Total collected so far: 3553
# Fetching page 124 for tag [nlp]...
#  Total collected so far: 3583
# Fetching page 125 for tag [nlp]...
#  Total collected so far: 3613
# Fetching page 126 for tag [nlp]...
#  Total collected so far: 3643
# Fetching page 127 for tag [nlp]...
#  Total collected so far: 3673
# Fetching page 128 for tag [nlp]...
#  Total collected so far: 3703
# Fetching page 129 for tag [nlp]...
#  Total collected so far: 3733
# Fetching page 130 for tag [nlp]...
#  Total collected so far: 3763
# Fetching page 131 for tag [nlp]...
#  Total collected so far: 3793
# Fetching page 132 for tag [nlp]...
#  Total collected so far: 3823
# Fetching page 133 for tag [nlp]...
#  Total collected so far: 3853
# Fetching page 134 for tag [nlp]...
#  Total collected so far: 3883
# Fetching page 135 for tag [nlp]...
#  Total collected so far: 3913
# Fetching page 136 for tag [nlp]...
#  Total collected so far: 3943
# Fetching page 137 for tag [nlp]...
#  Total collected so far: 3973
# Fetching page 138 for tag [nlp]...
#  Total collected so far: 4003
# Fetching page 139 for tag [nlp]...
#  Total collected so far: 4033
# Fetching page 140 for tag [nlp]...
#  Total collected so far: 4063
# Fetching page 141 for tag [nlp]...
#  Total collected so far: 4093
# Fetching page 142 for tag [nlp]...
#  Total collected so far: 4123
# Fetching page 143 for tag [nlp]...
#  Total collected so far: 4153
# Fetching page 144 for tag [nlp]...
#  Total collected so far: 4183
# Fetching page 145 for tag [nlp]...
#  Total collected so far: 4213
# Fetching page 146 for tag [nlp]...
#  Total collected so far: 4243
# Fetching page 147 for tag [nlp]...
#  Total collected so far: 4273
# Fetching page 148 for tag [nlp]...
#  Total collected so far: 4303
# Fetching page 149 for tag [nlp]...
#  Total collected so far: 4333
# Fetching page 150 for tag [nlp]...
#  Total collected so far: 4363
# Fetching page 151 for tag [nlp]...
#  Total collected so far: 4393
# Fetching page 152 for tag [nlp]...
#  Total collected so far: 4423
# Fetching page 153 for tag [nlp]...
#  Total collected so far: 4453
# Fetching page 154 for tag [nlp]...
#  Total collected so far: 4483
# Fetching page 155 for tag [nlp]...
#  Total collected so far: 4513
# Fetching page 156 for tag [nlp]...
#  Total collected so far: 4543
# Fetching page 157 for tag [nlp]...
#  Total collected so far: 4573
# Fetching page 158 for tag [nlp]...
#  Total collected so far: 4603
# Fetching page 159 for tag [nlp]...
#  Total collected so far: 4633
# Fetching page 160 for tag [nlp]...
#  Total collected so far: 4663
# Fetching page 161 for tag [nlp]...
#  Total collected so far: 4693
# Fetching page 162 for tag [nlp]...
#  Total collected so far: 4723
# Fetching page 163 for tag [nlp]...
#  Total collected so far: 4753
# Fetching page 164 for tag [nlp]...
#  Total collected so far: 4783
# Fetching page 165 for tag [nlp]...
#  Total collected so far: 4813
# Fetching page 166 for tag [nlp]...
#  Total collected so far: 4843
# Fetching page 167 for tag [nlp]...
#  Total collected so far: 4873
# Fetching page 168 for tag [nlp]...
#  Total collected so far: 4903
# Fetching page 169 for tag [nlp]...
#  Total collected so far: 4933
# Fetching page 170 for tag [nlp]...
#  Total collected so far: 4963
# Fetching page 171 for tag [nlp]...
#  Total collected so far: 4993
# Fetching page 172 for tag [nlp]...
#  Total collected so far: 5023
# Fetching page 173 for tag [nlp]...
#  Total collected so far: 5053
# Fetching page 174 for tag [nlp]...
#  Total collected so far: 5083
# Fetching page 175 for tag [nlp]...
#  Total collected so far: 5113
# Fetching page 176 for tag [nlp]...
#  Total collected so far: 5143
# Fetching page 177 for tag [nlp]...
#  Total collected so far: 5173
# Fetching page 178 for tag [nlp]...
#  Total collected so far: 5203
# Fetching page 179 for tag [nlp]...
#  Total collected so far: 5233
# Fetching page 180 for tag [nlp]...
#  Total collected so far: 5263
# Fetching page 181 for tag [nlp]...
#  Total collected so far: 5293
# Fetching page 182 for tag [nlp]...
#  Total collected so far: 5323
# Fetching page 183 for tag [nlp]...
#  Total collected so far: 5353
# Fetching page 184 for tag [nlp]...
#  Total collected so far: 5383
# Fetching page 185 for tag [nlp]...
#  Total collected so far: 5413
# Fetching page 186 for tag [nlp]...
#  Total collected so far: 5443
# Fetching page 187 for tag [nlp]...
#  Total collected so far: 5473
# Fetching page 188 for tag [nlp]...
#  Total collected so far: 5503
# Fetching page 189 for tag [nlp]...
#  Total collected so far: 5533
# Fetching page 190 for tag [nlp]...
#  Total collected so far: 5563
# Fetching page 191 for tag [nlp]...
#  Total collected so far: 5593
# Fetching page 192 for tag [nlp]...
#  Total collected so far: 5623
# Fetching page 193 for tag [nlp]...
#  Total collected so far: 5653
# Fetching page 194 for tag [nlp]...
#  Total collected so far: 5683
# Fetching page 195 for tag [nlp]...
#  Total collected so far: 5713
# Fetching page 196 for tag [nlp]...
#  Total collected so far: 5743
# Fetching page 197 for tag [nlp]...
#  Total collected so far: 5773
# Fetching page 198 for tag [nlp]...
#  Total collected so far: 5803
# Fetching page 199 for tag [nlp]...
#  Total collected so far: 5833
# Fetching page 200 for tag [nlp]...
#  Total collected so far: 5863
# Fetching page 1 for tag [nltk]...
#  Total collected so far: 5889
# Fetching page 2 for tag [nltk]...
#  Total collected so far: 5914
# Fetching page 3 for tag [nltk]...
#  Total collected so far: 5944
# Fetching page 4 for tag [nltk]...
#  Total collected so far: 5974
# Fetching page 5 for tag [nltk]...
#  Total collected so far: 6004
# Fetching page 6 for tag [nltk]...
#  Total collected so far: 6034
# Fetching page 7 for tag [nltk]...
#  Total collected so far: 6064
# Fetching page 8 for tag [nltk]...
#  Total collected so far: 6094
# Fetching page 9 for tag [nltk]...
#  Total collected so far: 6124
# Fetching page 10 for tag [nltk]...
#  Total collected so far: 6154
# Fetching page 11 for tag [nltk]...
#  Total collected so far: 6184
# Fetching page 12 for tag [nltk]...
#  Total collected so far: 6214
# Fetching page 13 for tag [nltk]...
#  Total collected so far: 6244
# Fetching page 14 for tag [nltk]...
#  Total collected so far: 6274
# Fetching page 15 for tag [nltk]...
#  Total collected so far: 6304
# Fetching page 16 for tag [nltk]...
#  Total collected so far: 6334
# Fetching page 17 for tag [nltk]...
#  Total collected so far: 6364
# Fetching page 18 for tag [nltk]...
#  Total collected so far: 6394
# Fetching page 19 for tag [nltk]...
#  Total collected so far: 6424
# Fetching page 20 for tag [nltk]...
#  Total collected so far: 6454
# Fetching page 21 for tag [nltk]...
#  Total collected so far: 6484
# Fetching page 22 for tag [nltk]...
#  Total collected so far: 6514
# Fetching page 23 for tag [nltk]...
#  Total collected so far: 6544
# Fetching page 24 for tag [nltk]...
#  Total collected so far: 6574
# Fetching page 25 for tag [nltk]...
#  Total collected so far: 6604
# Fetching page 26 for tag [nltk]...
#  Total collected so far: 6634
# Fetching page 27 for tag [nltk]...
#  Total collected so far: 6664
# Fetching page 28 for tag [nltk]...
#  Total collected so far: 6694
# Fetching page 29 for tag [nltk]...
#  Total collected so far: 6724
# Fetching page 30 for tag [nltk]...
#  Total collected so far: 6754
# Fetching page 31 for tag [nltk]...
#  Total collected so far: 6784
# Fetching page 32 for tag [nltk]...
#  Total collected so far: 6814
# Fetching page 33 for tag [nltk]...
#  Total collected so far: 6844
# Fetching page 34 for tag [nltk]...
#  Total collected so far: 6874
# Fetching page 35 for tag [nltk]...
#  Total collected so far: 6904
# Fetching page 36 for tag [nltk]...
#  Total collected so far: 6934
# Fetching page 37 for tag [nltk]...
#  Total collected so far: 6964
# Fetching page 38 for tag [nltk]...
#  Total collected so far: 6994
# Fetching page 39 for tag [nltk]...
#  Total collected so far: 7024
# Fetching page 40 for tag [nltk]...
#  Total collected so far: 7054
# Fetching page 41 for tag [nltk]...
#  Total collected so far: 7084
# Fetching page 42 for tag [nltk]...
#  Total collected so far: 7114
# Fetching page 43 for tag [nltk]...
#  Total collected so far: 7144
# Fetching page 44 for tag [nltk]...
#  Total collected so far: 7174
# Fetching page 45 for tag [nltk]...
#  Total collected so far: 7204
# Fetching page 46 for tag [nltk]...
#  Total collected so far: 7234
# Fetching page 47 for tag [nltk]...
#  Total collected so far: 7264
# Fetching page 48 for tag [nltk]...
#  Total collected so far: 7294
# Fetching page 49 for tag [nltk]...
#  Total collected so far: 7324
# Fetching page 50 for tag [nltk]...
#  Total collected so far: 7354
# Fetching page 51 for tag [nltk]...
#  Total collected so far: 7384
# Fetching page 52 for tag [nltk]...
#  Total collected so far: 7414
# Fetching page 53 for tag [nltk]...
#  Total collected so far: 7444
# Fetching page 54 for tag [nltk]...
#  Total collected so far: 7474
# Fetching page 55 for tag [nltk]...
#  Total collected so far: 7504
# Fetching page 56 for tag [nltk]...
#  Total collected so far: 7534
# Fetching page 57 for tag [nltk]...
#  Total collected so far: 7564
# Fetching page 58 for tag [nltk]...
#  Total collected so far: 7594
# Fetching page 59 for tag [nltk]...
#  Total collected so far: 7624
# Fetching page 60 for tag [nltk]...
#  Total collected so far: 7654
# Fetching page 61 for tag [nltk]...
#  Total collected so far: 7684
# Fetching page 62 for tag [nltk]...
#  Total collected so far: 7714
# Fetching page 63 for tag [nltk]...
#  Total collected so far: 7744
# Fetching page 64 for tag [nltk]...
#  Total collected so far: 7774
# Fetching page 65 for tag [nltk]...
#  Total collected so far: 7804
# Fetching page 66 for tag [nltk]...
#  Total collected so far: 7834
# Fetching page 67 for tag [nltk]...
#  Total collected so far: 7864
# Fetching page 68 for tag [nltk]...
#  Total collected so far: 7894
# Fetching page 69 for tag [nltk]...
#  Total collected so far: 7924
# Fetching page 70 for tag [nltk]...
#  Total collected so far: 7954
# Fetching page 71 for tag [nltk]...
#  Total collected so far: 7984
# Fetching page 72 for tag [nltk]...
#  Total collected so far: 7986
# Fetching page 73 for tag [nltk]...
# No items found for tag [nltk], page 73
# Fetching page 1 for tag [spacy]...
#  Total collected so far: 8007
# Fetching page 2 for tag [spacy]...
#  Total collected so far: 8037
# Fetching page 3 for tag [spacy]...
#  Total collected so far: 8067
# Fetching page 4 for tag [spacy]...
#  Total collected so far: 8091
# Fetching page 5 for tag [spacy]...
#  Total collected so far: 8121
# Fetching page 6 for tag [spacy]...
#  Total collected so far: 8151
# Fetching page 7 for tag [spacy]...
#  Total collected so far: 8181
# Fetching page 8 for tag [spacy]...
#  Total collected so far: 8211
# Fetching page 9 for tag [spacy]...
#  Total collected so far: 8241
# Fetching page 10 for tag [spacy]...
#  Total collected so far: 8271
# Fetching page 11 for tag [spacy]...
#  Total collected so far: 8301
# Fetching page 12 for tag [spacy]...
#  Total collected so far: 8331
# Fetching page 13 for tag [spacy]...
#  Total collected so far: 8361
# Fetching page 14 for tag [spacy]...
#  Total collected so far: 8391
# Fetching page 15 for tag [spacy]...
#  Total collected so far: 8421
# Fetching page 16 for tag [spacy]...
#  Total collected so far: 8451
# Fetching page 17 for tag [spacy]...
#  Total collected so far: 8481
# Fetching page 18 for tag [spacy]...
#  Total collected so far: 8511
# Fetching page 19 for tag [spacy]...
#  Total collected so far: 8541
# Fetching page 20 for tag [spacy]...
#  Total collected so far: 8571
# Fetching page 21 for tag [spacy]...
#  Total collected so far: 8601
# Fetching page 22 for tag [spacy]...
#  Total collected so far: 8631
# Fetching page 23 for tag [spacy]...
#  Total collected so far: 8661
# Fetching page 24 for tag [spacy]...
#  Total collected so far: 8691
# Fetching page 25 for tag [spacy]...
#  Total collected so far: 8721
# Fetching page 26 for tag [spacy]...
#  Total collected so far: 8751
# Fetching page 27 for tag [spacy]...
#  Total collected so far: 8781
# Fetching page 28 for tag [spacy]...
#  Total collected so far: 8811
# Fetching page 29 for tag [spacy]...
#  Total collected so far: 8841
# Fetching page 30 for tag [spacy]...
#  Total collected so far: 8871
# Fetching page 31 for tag [spacy]...
#  Total collected so far: 8901
# Fetching page 32 for tag [spacy]...
#  Total collected so far: 8931
# Fetching page 33 for tag [spacy]...
#  Total collected so far: 8961
# Fetching page 34 for tag [spacy]...
#  Total collected so far: 8991
# Fetching page 35 for tag [spacy]...
#  Total collected so far: 9021
# Fetching page 36 for tag [spacy]...
#  Total collected so far: 9051
# Fetching page 37 for tag [spacy]...
#  Total collected so far: 9081
# Fetching page 38 for tag [spacy]...
#  Total collected so far: 9111
# Fetching page 39 for tag [spacy]...
#  Total collected so far: 9121
# Fetching page 40 for tag [spacy]...
# No items found for tag [spacy], page 40
# Fetching page 1 for tag [transformers]...
# No items found for tag [transformers], page 1
# Fetching page 1 for tag [text-classification]...
#  Total collected so far: 9149
# Fetching page 2 for tag [text-classification]...
#  Total collected so far: 9172
# Fetching page 3 for tag [text-classification]...
#  Total collected so far: 9196
# Fetching page 4 for tag [text-classification]...
#  Total collected so far: 9226
# Fetching page 5 for tag [text-classification]...
#  Total collected so far: 9256
# Fetching page 6 for tag [text-classification]...
#  Total collected so far: 9286
# Fetching page 7 for tag [text-classification]...
#  Total collected so far: 9316
# Fetching page 8 for tag [text-classification]...
#  Total collected so far: 9346
# Fetching page 9 for tag [text-classification]...
#  Total collected so far: 9376
# Fetching page 10 for tag [text-classification]...
#  Total collected so far: 9406
# Fetching page 11 for tag [text-classification]...
#  Total collected so far: 9436
# Fetching page 12 for tag [text-classification]...
#  Total collected so far: 9466
# Fetching page 13 for tag [text-classification]...
#  Total collected so far: 9496
# Fetching page 14 for tag [text-classification]...
#  Total collected so far: 9526
# Fetching page 15 for tag [text-classification]...
#  Total collected so far: 9556
# Fetching page 16 for tag [text-classification]...
#  Total collected so far: 9586
# Fetching page 17 for tag [text-classification]...
#  Total collected so far: 9615
# Fetching page 18 for tag [text-classification]...
# No items found for tag [text-classification], page 18
#  Done! Saved 9615 valid Q&A posts to stackoverflow_nlp_posts_with_answers.json

# %%
import requests
import time
import json

# API configuration
TAGS = ["nlp", "nltk", "spacy", "transformers", "text-classification"]
SITE = "stackoverflow"
PAGE_SIZE = 100
START_PAGE = 19
MAX_PAGES = 200
OUTPUT_FILE = "stackoverflow_nlp_posts_part2.json"
API_KEY = "rl_ikc5MimeHf8zgfjLcqbwYV5rr"
TARGET_COUNT = 20000

all_questions = []
valid_question_count = 0

# Loop through tags and paginated questions
for tag in TAGS:
    for page in range(START_PAGE, MAX_PAGES + 1):
        print(f"Fetching page {page} for tag [{tag}]...")

        url = "https://api.stackexchange.com/2.3/questions"
        params = {
            "page": page,
            "pagesize": PAGE_SIZE,
            "order": "desc",
            "sort": "creation",
            "tagged": tag,
            "site": SITE,
            "filter": "withbody",
            "key": API_KEY
        }

        response = requests.get(url, params=params)
        if response.status_code != 200:
            print(f"Error {response.status_code}: {response.text}")
            break

        try:
            data = response.json()
        except ValueError:
            print("Invalid JSON response. Skipping this page.")
            continue

        if "items" not in data or not data["items"]:
            print(f"No items found for tag [{tag}], page {page}")
            break

        # Filter questions that have accepted answers
        questions_with_answers = [
            item for item in data["items"] if item.get("accepted_answer_id")
        ]

        # Fetch bodies of accepted answers in batches
        accepted_ids = [str(q["accepted_answer_id"]) for q in questions_with_answers]
        id_batches = [accepted_ids[i:i+100] for i in range(0, len(accepted_ids), 100)]

        accepted_answers = {}
        for batch in id_batches:
            ids_str = ";".join(batch)
            ans_url = f"https://api.stackexchange.com/2.3/answers/{ids_str}"
            ans_params = {
                "site": SITE,
                "filter": "withbody",
                "key": API_KEY
            }
            ans_response = requests.get(ans_url, params=ans_params)
            if ans_response.status_code == 200:
                try:
                    ans_data = ans_response.json()
                    for ans in ans_data.get("items", []):
                        accepted_answers[ans["answer_id"]] = ans.get("body")
                except ValueError:
                    continue
            time.sleep(0.5)  

        # Merge question and its accepted answer into the dataset
        for item in questions_with_answers:
            if valid_question_count >= TARGET_COUNT:
                break

            aid = item["accepted_answer_id"]
            abody = accepted_answers.get(aid)

            if abody:
                question_data = {
                    "question_id": item.get("question_id"),
                    "title": item.get("title"),
                    "body": item.get("body"),
                    "tags": item.get("tags"),
                    "accepted_answer_id": aid,
                    "accepted_answer_body": abody,
                    "score": item.get("score")
                }
                all_questions.append(question_data)
                valid_question_count += 1

        print(f" Total collected so far: {valid_question_count}")
        time.sleep(0.5)

        if valid_question_count >= TARGET_COUNT:
            break
    if valid_question_count >= TARGET_COUNT:
        break

# Save all collected data to a JSON file
with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump(all_questions, f, indent=4)

print(f" Done! Saved {valid_question_count} new Q&A posts to {OUTPUT_FILE}")
# Out:
# Fetching page 19 for tag [nlp]...
#  Total collected so far: 29
# Fetching page 20 for tag [nlp]...
#  Total collected so far: 59
# Fetching page 21 for tag [nlp]...
#  Total collected so far: 89
# Fetching page 22 for tag [nlp]...
#  Total collected so far: 119
# Fetching page 23 for tag [nlp]...
#  Total collected so far: 149
# Fetching page 24 for tag [nlp]...
#  Total collected so far: 179
# Fetching page 25 for tag [nlp]...
#  Total collected so far: 209
# Fetching page 26 for tag [nlp]...
#  Total collected so far: 235
# Fetching page 27 for tag [nlp]...
#  Total collected so far: 265
# Fetching page 28 for tag [nlp]...
#  Total collected so far: 295
# Fetching page 29 for tag [nlp]...
#  Total collected so far: 325
# Fetching page 30 for tag [nlp]...
#  Total collected so far: 355
# Fetching page 31 for tag [nlp]...
#  Total collected so far: 385
# Fetching page 32 for tag [nlp]...
#  Total collected so far: 413
# Fetching page 33 for tag [nlp]...
#  Total collected so far: 443
# Fetching page 34 for tag [nlp]...
#  Total collected so far: 473
# Fetching page 35 for tag [nlp]...
#  Total collected so far: 503
# Fetching page 36 for tag [nlp]...
#  Total collected so far: 533
# Fetching page 37 for tag [nlp]...
#  Total collected so far: 563
# Fetching page 38 for tag [nlp]...
#  Total collected so far: 593
# Fetching page 39 for tag [nlp]...
#  Total collected so far: 623
# Fetching page 40 for tag [nlp]...
#  Total collected so far: 653
# Fetching page 41 for tag [nlp]...
#  Total collected so far: 683
# Fetching page 42 for tag [nlp]...
#  Total collected so far: 713
# Fetching page 43 for tag [nlp]...
#  Total collected so far: 743
# Fetching page 44 for tag [nlp]...
#  Total collected so far: 772
# Fetching page 45 for tag [nlp]...
#  Total collected so far: 801
# Fetching page 46 for tag [nlp]...
#  Total collected so far: 831
# Fetching page 47 for tag [nlp]...
#  Total collected so far: 861
# Fetching page 48 for tag [nlp]...
#  Total collected so far: 891
# Fetching page 49 for tag [nlp]...
#  Total collected so far: 921
# Fetching page 50 for tag [nlp]...
#  Total collected so far: 951
# Fetching page 51 for tag [nlp]...
#  Total collected so far: 981
# Fetching page 52 for tag [nlp]...
#  Total collected so far: 1011
# Fetching page 53 for tag [nlp]...
#  Total collected so far: 1041
# Fetching page 54 for tag [nlp]...
#  Total collected so far: 1071
# Fetching page 55 for tag [nlp]...
#  Total collected so far: 1101
# Fetching page 56 for tag [nlp]...
#  Total collected so far: 1131
# Fetching page 57 for tag [nlp]...
#  Total collected so far: 1161
# Fetching page 58 for tag [nlp]...
#  Total collected so far: 1191
# Fetching page 59 for tag [nlp]...
#  Total collected so far: 1221
# Fetching page 60 for tag [nlp]...
#  Total collected so far: 1251
# Fetching page 61 for tag [nlp]...
#  Total collected so far: 1281
# Fetching page 62 for tag [nlp]...
#  Total collected so far: 1311
# Fetching page 63 for tag [nlp]...
#  Total collected so far: 1341
# Fetching page 64 for tag [nlp]...
#  Total collected so far: 1371
# Fetching page 65 for tag [nlp]...
#  Total collected so far: 1401
# Fetching page 66 for tag [nlp]...
#  Total collected so far: 1431
# Fetching page 67 for tag [nlp]...
#  Total collected so far: 1461
# Fetching page 68 for tag [nlp]...
#  Total collected so far: 1491
# Fetching page 69 for tag [nlp]...
#  Total collected so far: 1521
# Fetching page 70 for tag [nlp]...
#  Total collected so far: 1551
# Fetching page 71 for tag [nlp]...
#  Total collected so far: 1581
# Fetching page 72 for tag [nlp]...
#  Total collected so far: 1611
# Fetching page 73 for tag [nlp]...
#  Total collected so far: 1641
# Fetching page 74 for tag [nlp]...
#  Total collected so far: 1671
# Fetching page 75 for tag [nlp]...
#  Total collected so far: 1701
# Fetching page 76 for tag [nlp]...
#  Total collected so far: 1731
# Fetching page 77 for tag [nlp]...
#  Total collected so far: 1761
# Fetching page 78 for tag [nlp]...
#  Total collected so far: 1791
# Fetching page 79 for tag [nlp]...
#  Total collected so far: 1821
# Fetching page 80 for tag [nlp]...
#  Total collected so far: 1851
# Fetching page 81 for tag [nlp]...
#  Total collected so far: 1881
# Fetching page 82 for tag [nlp]...
#  Total collected so far: 1911
# Fetching page 83 for tag [nlp]...
#  Total collected so far: 1941
# Fetching page 84 for tag [nlp]...
#  Total collected so far: 1971
# Fetching page 85 for tag [nlp]...
#  Total collected so far: 2001
# Fetching page 86 for tag [nlp]...
#  Total collected so far: 2031
# Fetching page 87 for tag [nlp]...
#  Total collected so far: 2061
# Fetching page 88 for tag [nlp]...
#  Total collected so far: 2090
# Fetching page 89 for tag [nlp]...
#  Total collected so far: 2120
# Fetching page 90 for tag [nlp]...
#  Total collected so far: 2150
# Fetching page 91 for tag [nlp]...
#  Total collected so far: 2180
# Fetching page 92 for tag [nlp]...
#  Total collected so far: 2210
# Fetching page 93 for tag [nlp]...
#  Total collected so far: 2240
# Fetching page 94 for tag [nlp]...
#  Total collected so far: 2270
# Fetching page 95 for tag [nlp]...
#  Total collected so far: 2300
# Fetching page 96 for tag [nlp]...
#  Total collected so far: 2330
# Fetching page 97 for tag [nlp]...
#  Total collected so far: 2360
# Fetching page 98 for tag [nlp]...
#  Total collected so far: 2390
# Fetching page 99 for tag [nlp]...
#  Total collected so far: 2420
# Fetching page 100 for tag [nlp]...
#  Total collected so far: 2450
# Fetching page 101 for tag [nlp]...
#  Total collected so far: 2480
# Fetching page 102 for tag [nlp]...
#  Total collected so far: 2510
# Fetching page 103 for tag [nlp]...
#  Total collected so far: 2540
# Fetching page 104 for tag [nlp]...
#  Total collected so far: 2570
# Fetching page 105 for tag [nlp]...
#  Total collected so far: 2600
# Fetching page 106 for tag [nlp]...
#  Total collected so far: 2630
# Fetching page 107 for tag [nlp]...
#  Total collected so far: 2660
# Fetching page 108 for tag [nlp]...
#  Total collected so far: 2690
# Fetching page 109 for tag [nlp]...
#  Total collected so far: 2720
# Fetching page 110 for tag [nlp]...
#  Total collected so far: 2750
# Fetching page 111 for tag [nlp]...
#  Total collected so far: 2780
# Fetching page 112 for tag [nlp]...
#  Total collected so far: 2810
# Fetching page 113 for tag [nlp]...
#  Total collected so far: 2840
# Fetching page 114 for tag [nlp]...
#  Total collected so far: 2870
# Fetching page 115 for tag [nlp]...
#  Total collected so far: 2900
# Fetching page 116 for tag [nlp]...
#  Total collected so far: 2930
# Fetching page 117 for tag [nlp]...
#  Total collected so far: 2960
# Fetching page 118 for tag [nlp]...
#  Total collected so far: 2990
# Fetching page 119 for tag [nlp]...
#  Total collected so far: 3020
# Fetching page 120 for tag [nlp]...
#  Total collected so far: 3050
# Fetching page 121 for tag [nlp]...
#  Total collected so far: 3080
# Fetching page 122 for tag [nlp]...
#  Total collected so far: 3110
# Fetching page 123 for tag [nlp]...
#  Total collected so far: 3140
# Fetching page 124 for tag [nlp]...
#  Total collected so far: 3170
# Fetching page 125 for tag [nlp]...
#  Total collected so far: 3200
# Fetching page 126 for tag [nlp]...
#  Total collected so far: 3230
# Fetching page 127 for tag [nlp]...
#  Total collected so far: 3260
# Fetching page 128 for tag [nlp]...
#  Total collected so far: 3290
# Fetching page 129 for tag [nlp]...
#  Total collected so far: 3320
# Fetching page 130 for tag [nlp]...
#  Total collected so far: 3350
# Fetching page 131 for tag [nlp]...
#  Total collected so far: 3380
# Fetching page 132 for tag [nlp]...
#  Total collected so far: 3410
# Fetching page 133 for tag [nlp]...
#  Total collected so far: 3440
# Fetching page 134 for tag [nlp]...
#  Total collected so far: 3470
# Fetching page 135 for tag [nlp]...
#  Total collected so far: 3500
# Fetching page 136 for tag [nlp]...
#  Total collected so far: 3530
# Fetching page 137 for tag [nlp]...
#  Total collected so far: 3560
# Fetching page 138 for tag [nlp]...
#  Total collected so far: 3590
# Fetching page 139 for tag [nlp]...
#  Total collected so far: 3620
# Fetching page 140 for tag [nlp]...
#  Total collected so far: 3650
# Fetching page 141 for tag [nlp]...
#  Total collected so far: 3680
# Fetching page 142 for tag [nlp]...
#  Total collected so far: 3710
# Fetching page 143 for tag [nlp]...
#  Total collected so far: 3740
# Fetching page 144 for tag [nlp]...
#  Total collected so far: 3770
# Fetching page 145 for tag [nlp]...
#  Total collected so far: 3800
# Fetching page 146 for tag [nlp]...
#  Total collected so far: 3830
# Fetching page 147 for tag [nlp]...
#  Total collected so far: 3860
# Fetching page 148 for tag [nlp]...
#  Total collected so far: 3890
# Fetching page 149 for tag [nlp]...
#  Total collected so far: 3920
# Fetching page 150 for tag [nlp]...
#  Total collected so far: 3950
# Fetching page 151 for tag [nlp]...
#  Total collected so far: 3980
# Fetching page 152 for tag [nlp]...
#  Total collected so far: 4010
# Fetching page 153 for tag [nlp]...
#  Total collected so far: 4040
# Fetching page 154 for tag [nlp]...
#  Total collected so far: 4070
# Fetching page 155 for tag [nlp]...
#  Total collected so far: 4100
# Fetching page 156 for tag [nlp]...
#  Total collected so far: 4130
# Fetching page 157 for tag [nlp]...
#  Total collected so far: 4160
# Fetching page 158 for tag [nlp]...
#  Total collected so far: 4190
# Fetching page 159 for tag [nlp]...
#  Total collected so far: 4220
# Fetching page 160 for tag [nlp]...
#  Total collected so far: 4250
# Fetching page 161 for tag [nlp]...
#  Total collected so far: 4280
# Fetching page 162 for tag [nlp]...
#  Total collected so far: 4310
# Fetching page 163 for tag [nlp]...
#  Total collected so far: 4340
# Fetching page 164 for tag [nlp]...
#  Total collected so far: 4370
# Fetching page 165 for tag [nlp]...
#  Total collected so far: 4400
# Fetching page 166 for tag [nlp]...
#  Total collected so far: 4430
# Fetching page 167 for tag [nlp]...
#  Total collected so far: 4460
# Fetching page 168 for tag [nlp]...
#  Total collected so far: 4490
# Fetching page 169 for tag [nlp]...
#  Total collected so far: 4520
# Fetching page 170 for tag [nlp]...
#  Total collected so far: 4550
# Fetching page 171 for tag [nlp]...
#  Total collected so far: 4580
# Fetching page 172 for tag [nlp]...
#  Total collected so far: 4610
# Fetching page 173 for tag [nlp]...
#  Total collected so far: 4640
# Fetching page 174 for tag [nlp]...
#  Total collected so far: 4670
# Fetching page 175 for tag [nlp]...
#  Total collected so far: 4700
# Fetching page 176 for tag [nlp]...
#  Total collected so far: 4730
# Fetching page 177 for tag [nlp]...
#  Total collected so far: 4760
# Fetching page 178 for tag [nlp]...
#  Total collected so far: 4790
# Fetching page 179 for tag [nlp]...
#  Total collected so far: 4820
# Fetching page 180 for tag [nlp]...
#  Total collected so far: 4850
# Fetching page 181 for tag [nlp]...
#  Total collected so far: 4880
# Fetching page 182 for tag [nlp]...
#  Total collected so far: 4910
# Fetching page 183 for tag [nlp]...
#  Total collected so far: 4940
# Fetching page 184 for tag [nlp]...
#  Total collected so far: 4970
# Fetching page 185 for tag [nlp]...
#  Total collected so far: 5000
# Fetching page 186 for tag [nlp]...
#  Total collected so far: 5030
# Fetching page 187 for tag [nlp]...
#  Total collected so far: 5060
# Fetching page 188 for tag [nlp]...
#  Total collected so far: 5090
# Fetching page 189 for tag [nlp]...
#  Total collected so far: 5120
# Fetching page 190 for tag [nlp]...
#  Total collected so far: 5150
# Fetching page 191 for tag [nlp]...
#  Total collected so far: 5180
# Fetching page 192 for tag [nlp]...
#  Total collected so far: 5210
# Fetching page 193 for tag [nlp]...
#  Total collected so far: 5240
# Fetching page 194 for tag [nlp]...
#  Total collected so far: 5270
# Fetching page 195 for tag [nlp]...
#  Total collected so far: 5300
# Fetching page 196 for tag [nlp]...
#  Total collected so far: 5330
# Fetching page 197 for tag [nlp]...
#  Total collected so far: 5360
# Fetching page 198 for tag [nlp]...
#  Total collected so far: 5390
# Fetching page 199 for tag [nlp]...
#  Total collected so far: 5420
# Fetching page 200 for tag [nlp]...
#  Total collected so far: 5450
# Fetching page 19 for tag [nltk]...
#  Total collected so far: 5480
# Fetching page 20 for tag [nltk]...
#  Total collected so far: 5510
# Fetching page 21 for tag [nltk]...
#  Total collected so far: 5540
# Fetching page 22 for tag [nltk]...
#  Total collected so far: 5570
# Fetching page 23 for tag [nltk]...
#  Total collected so far: 5600
# Fetching page 24 for tag [nltk]...
#  Total collected so far: 5630
# Fetching page 25 for tag [nltk]...
#  Total collected so far: 5660
# Fetching page 26 for tag [nltk]...
#  Total collected so far: 5690
# Fetching page 27 for tag [nltk]...
#  Total collected so far: 5720
# Fetching page 28 for tag [nltk]...
#  Total collected so far: 5750
# Fetching page 29 for tag [nltk]...
#  Total collected so far: 5780
# Fetching page 30 for tag [nltk]...
#  Total collected so far: 5810
# Fetching page 31 for tag [nltk]...
#  Total collected so far: 5840
# Fetching page 32 for tag [nltk]...
#  Total collected so far: 5870
# Fetching page 33 for tag [nltk]...
#  Total collected so far: 5900
# Fetching page 34 for tag [nltk]...
#  Total collected so far: 5930
# Fetching page 35 for tag [nltk]...
#  Total collected so far: 5960
# Fetching page 36 for tag [nltk]...
#  Total collected so far: 5990
# Fetching page 37 for tag [nltk]...
#  Total collected so far: 6020
# Fetching page 38 for tag [nltk]...
#  Total collected so far: 6050
# Fetching page 39 for tag [nltk]...
#  Total collected so far: 6080
# Fetching page 40 for tag [nltk]...
#  Total collected so far: 6110
# Fetching page 41 for tag [nltk]...
#  Total collected so far: 6140
# Fetching page 42 for tag [nltk]...
#  Total collected so far: 6170
# Fetching page 43 for tag [nltk]...
#  Total collected so far: 6200
# Fetching page 44 for tag [nltk]...
#  Total collected so far: 6230
# Fetching page 45 for tag [nltk]...
#  Total collected so far: 6260
# Fetching page 46 for tag [nltk]...
#  Total collected so far: 6290
# Fetching page 47 for tag [nltk]...
#  Total collected so far: 6320
# Fetching page 48 for tag [nltk]...
#  Total collected so far: 6350
# Fetching page 49 for tag [nltk]...
#  Total collected so far: 6380
# Fetching page 50 for tag [nltk]...
#  Total collected so far: 6410
# Fetching page 51 for tag [nltk]...
#  Total collected so far: 6440
# Fetching page 52 for tag [nltk]...
#  Total collected so far: 6470
# Fetching page 53 for tag [nltk]...
#  Total collected so far: 6500
# Fetching page 54 for tag [nltk]...
#  Total collected so far: 6530
# Fetching page 55 for tag [nltk]...
#  Total collected so far: 6560
# Fetching page 56 for tag [nltk]...
#  Total collected so far: 6590
# Fetching page 57 for tag [nltk]...
#  Total collected so far: 6620
# Fetching page 58 for tag [nltk]...
#  Total collected so far: 6650
# Fetching page 59 for tag [nltk]...
#  Total collected so far: 6680
# Fetching page 60 for tag [nltk]...
#  Total collected so far: 6710
# Fetching page 61 for tag [nltk]...
#  Total collected so far: 6740
# Fetching page 62 for tag [nltk]...
#  Total collected so far: 6770
# Fetching page 63 for tag [nltk]...
#  Total collected so far: 6800
# Fetching page 64 for tag [nltk]...
#  Total collected so far: 6830
# Fetching page 65 for tag [nltk]...
#  Total collected so far: 6860
# Fetching page 66 for tag [nltk]...
#  Total collected so far: 6890
# Fetching page 67 for tag [nltk]...
#  Total collected so far: 6920
# Fetching page 68 for tag [nltk]...
#  Total collected so far: 6950
# Fetching page 69 for tag [nltk]...
#  Total collected so far: 6980
# Fetching page 70 for tag [nltk]...
#  Total collected so far: 7010
# Fetching page 71 for tag [nltk]...
#  Total collected so far: 7040
# Fetching page 72 for tag [nltk]...
#  Total collected so far: 7042
# Fetching page 73 for tag [nltk]...
# No items found for tag [nltk], page 73
# Fetching page 19 for tag [spacy]...
#  Total collected so far: 7072
# Fetching page 20 for tag [spacy]...
#  Total collected so far: 7102
# Fetching page 21 for tag [spacy]...
#  Total collected so far: 7132
# Fetching page 22 for tag [spacy]...
#  Total collected so far: 7162
# Fetching page 23 for tag [spacy]...
#  Total collected so far: 7192
# Fetching page 24 for tag [spacy]...
#  Total collected so far: 7222
# Fetching page 25 for tag [spacy]...
#  Total collected so far: 7252
# Fetching page 26 for tag [spacy]...
#  Total collected so far: 7282
# Fetching page 27 for tag [spacy]...
#  Total collected so far: 7312
# Fetching page 28 for tag [spacy]...
#  Total collected so far: 7342
# Fetching page 29 for tag [spacy]...
#  Total collected so far: 7372
# Fetching page 30 for tag [spacy]...
#  Total collected so far: 7402
# Fetching page 31 for tag [spacy]...
#  Total collected so far: 7432
# Fetching page 32 for tag [spacy]...
#  Total collected so far: 7462
# Fetching page 33 for tag [spacy]...
#  Total collected so far: 7492
# Fetching page 34 for tag [spacy]...
#  Total collected so far: 7522
# Fetching page 35 for tag [spacy]...
#  Total collected so far: 7552
# Fetching page 36 for tag [spacy]...
#  Total collected so far: 7582
# Fetching page 37 for tag [spacy]...
#  Total collected so far: 7612
# Fetching page 38 for tag [spacy]...
#  Total collected so far: 7642
# Fetching page 39 for tag [spacy]...
#  Total collected so far: 7652
# Fetching page 40 for tag [spacy]...
# No items found for tag [spacy], page 40
# Fetching page 19 for tag [transformers]...
# No items found for tag [transformers], page 19
# Fetching page 19 for tag [text-classification]...
# No items found for tag [text-classification], page 19
#  Done! Saved 7652 new Q&A posts to stackoverflow_nlp_posts_part2.json

# %%
import requests
import time
import json

# API configuration
TAGS = ["nlp", "nltk", "spacy", "transformers", "text-classification"]
SITE = "stackoverflow"
PAGE_SIZE = 100
START_PAGE = 32
MAX_PAGES = 200
OUTPUT_FILE = "stackoverflow_nlp_posts_part3.json"
API_KEY = "rl_hgq4LDMkXEWV6kz23rmXAam1R"
TARGET_COUNT = 5000

all_questions = []
valid_question_count = 0

# Loop through tags and paginated questions
for tag in TAGS:
    for page in range(START_PAGE, MAX_PAGES + 1):
        print(f"Fetching page {page} for tag [{tag}]...")

        url = "https://api.stackexchange.com/2.3/questions"
        params = {
            "page": page,
            "pagesize": PAGE_SIZE,
            "order": "desc",
            "sort": "creation",
            "tagged": tag,
            "site": SITE,
            "filter": "withbody",
            "key": API_KEY
        }

        response = requests.get(url, params=params)
        if response.status_code != 200:
            print(f"Error {response.status_code}: {response.text}")
            break

        try:
            data = response.json()
        except ValueError:
            print("Invalid JSON response. Skipping this page.")
            continue

        if "items" not in data or not data["items"]:
            print(f"No items found for tag [{tag}], page {page}")
            break

        # Filter questions that have accepted answers
        questions_with_answers = [
            item for item in data["items"] if item.get("accepted_answer_id")
        ]

        # Fetch bodies of accepted answers in batches
        accepted_ids = [str(q["accepted_answer_id"]) for q in questions_with_answers]
        id_batches = [accepted_ids[i:i+100] for i in range(0, len(accepted_ids), 100)]

        accepted_answers = {}
        for batch in id_batches:
            ids_str = ";".join(batch)
            ans_url = f"https://api.stackexchange.com/2.3/answers/{ids_str}"
            ans_params = {
                "site": SITE,
                "filter": "withbody",
                "key": API_KEY
            }
            ans_response = requests.get(ans_url, params=ans_params)
            if ans_response.status_code == 200:
                try:
                    ans_data = ans_response.json()
                    for ans in ans_data.get("items", []):
                        accepted_answers[ans["answer_id"]] = ans.get("body")
                except ValueError:
                    continue
            time.sleep(0.5)  

        # Merge question and its accepted answer into the dataset
        for item in questions_with_answers:
            if valid_question_count >= TARGET_COUNT:
                break

            aid = item["accepted_answer_id"]
            abody = accepted_answers.get(aid)

            if abody:
                question_data = {
                    "question_id": item.get("question_id"),
                    "title": item.get("title"),
                    "body": item.get("body"),
                    "tags": item.get("tags"),
                    "accepted_answer_id": aid,
                    "accepted_answer_body": abody,
                    "score": item.get("score")
                }
                all_questions.append(question_data)
                valid_question_count += 1

        print(f" Total collected so far: {valid_question_count}")
        time.sleep(0.5)

        if valid_question_count >= TARGET_COUNT:
            break
    if valid_question_count >= TARGET_COUNT:
        break

# Save all collected data to a JSON file
with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump(all_questions, f, indent=4)

print(f" Done! Saved {valid_question_count} new Q&A posts to {OUTPUT_FILE}")
# Out:
# Fetching page 32 for tag [nlp]...
#  Total collected so far: 28
# Fetching page 33 for tag [nlp]...
#  Total collected so far: 58
# Fetching page 34 for tag [nlp]...
#  Total collected so far: 88
# Fetching page 35 for tag [nlp]...
#  Total collected so far: 118
# Fetching page 36 for tag [nlp]...
#  Total collected so far: 148
# Fetching page 37 for tag [nlp]...
#  Total collected so far: 178
# Fetching page 38 for tag [nlp]...
#  Total collected so far: 208
# Fetching page 39 for tag [nlp]...
#  Total collected so far: 238
# Fetching page 40 for tag [nlp]...
#  Total collected so far: 268
# Fetching page 41 for tag [nlp]...
#  Total collected so far: 298
# Fetching page 42 for tag [nlp]...
#  Total collected so far: 328
# Fetching page 43 for tag [nlp]...
#  Total collected so far: 358
# Fetching page 44 for tag [nlp]...
#  Total collected so far: 387
# Fetching page 45 for tag [nlp]...
#  Total collected so far: 416
# Fetching page 46 for tag [nlp]...
#  Total collected so far: 446
# Fetching page 47 for tag [nlp]...
#  Total collected so far: 476
# Fetching page 48 for tag [nlp]...
#  Total collected so far: 506
# Fetching page 49 for tag [nlp]...
#  Total collected so far: 536
# Fetching page 50 for tag [nlp]...
#  Total collected so far: 566
# Fetching page 51 for tag [nlp]...
#  Total collected so far: 596
# Fetching page 52 for tag [nlp]...
#  Total collected so far: 626
# Fetching page 53 for tag [nlp]...
#  Total collected so far: 656
# Fetching page 54 for tag [nlp]...
#  Total collected so far: 686
# Fetching page 55 for tag [nlp]...
#  Total collected so far: 716
# Fetching page 56 for tag [nlp]...
#  Total collected so far: 746
# Fetching page 57 for tag [nlp]...
#  Total collected so far: 776
# Fetching page 58 for tag [nlp]...
#  Total collected so far: 806
# Fetching page 59 for tag [nlp]...
#  Total collected so far: 836
# Fetching page 60 for tag [nlp]...
#  Total collected so far: 866
# Fetching page 61 for tag [nlp]...
#  Total collected so far: 896
# Fetching page 62 for tag [nlp]...
#  Total collected so far: 926
# Fetching page 63 for tag [nlp]...
#  Total collected so far: 956
# Fetching page 64 for tag [nlp]...
#  Total collected so far: 986
# Fetching page 65 for tag [nlp]...
#  Total collected so far: 1016
# Fetching page 66 for tag [nlp]...
#  Total collected so far: 1046
# Fetching page 67 for tag [nlp]...
#  Total collected so far: 1076
# Fetching page 68 for tag [nlp]...
#  Total collected so far: 1106
# Fetching page 69 for tag [nlp]...
#  Total collected so far: 1136
# Fetching page 70 for tag [nlp]...
#  Total collected so far: 1166
# Fetching page 71 for tag [nlp]...
#  Total collected so far: 1196
# Fetching page 72 for tag [nlp]...
#  Total collected so far: 1226
# Fetching page 73 for tag [nlp]...
#  Total collected so far: 1256
# Fetching page 74 for tag [nlp]...
#  Total collected so far: 1286
# Fetching page 75 for tag [nlp]...
#  Total collected so far: 1316
# Fetching page 76 for tag [nlp]...
#  Total collected so far: 1346
# Fetching page 77 for tag [nlp]...
#  Total collected so far: 1376
# Fetching page 78 for tag [nlp]...
#  Total collected so far: 1406
# Fetching page 79 for tag [nlp]...
#  Total collected so far: 1436
# Fetching page 80 for tag [nlp]...
#  Total collected so far: 1466
# Fetching page 81 for tag [nlp]...
#  Total collected so far: 1496
# Fetching page 82 for tag [nlp]...
#  Total collected so far: 1526
# Fetching page 83 for tag [nlp]...
#  Total collected so far: 1556
# Fetching page 84 for tag [nlp]...
#  Total collected so far: 1586
# Fetching page 85 for tag [nlp]...
#  Total collected so far: 1616
# Fetching page 86 for tag [nlp]...
#  Total collected so far: 1646
# Fetching page 87 for tag [nlp]...
#  Total collected so far: 1676
# Fetching page 88 for tag [nlp]...
#  Total collected so far: 1705
# Fetching page 89 for tag [nlp]...
#  Total collected so far: 1735
# Fetching page 90 for tag [nlp]...
#  Total collected so far: 1765
# Fetching page 91 for tag [nlp]...
#  Total collected so far: 1795
# Fetching page 92 for tag [nlp]...
#  Total collected so far: 1825
# Fetching page 93 for tag [nlp]...
#  Total collected so far: 1855
# Fetching page 94 for tag [nlp]...
#  Total collected so far: 1885
# Fetching page 95 for tag [nlp]...
#  Total collected so far: 1915
# Fetching page 96 for tag [nlp]...
#  Total collected so far: 1945
# Fetching page 97 for tag [nlp]...
#  Total collected so far: 1975
# Fetching page 98 for tag [nlp]...
#  Total collected so far: 2005
# Fetching page 99 for tag [nlp]...
#  Total collected so far: 2035
# Fetching page 100 for tag [nlp]...
#  Total collected so far: 2065
# Fetching page 101 for tag [nlp]...
#  Total collected so far: 2095
# Fetching page 102 for tag [nlp]...
#  Total collected so far: 2125
# Fetching page 103 for tag [nlp]...
#  Total collected so far: 2155
# Fetching page 104 for tag [nlp]...
#  Total collected so far: 2185
# Fetching page 105 for tag [nlp]...
#  Total collected so far: 2215
# Fetching page 106 for tag [nlp]...
#  Total collected so far: 2245
# Fetching page 107 for tag [nlp]...
#  Total collected so far: 2275
# Fetching page 108 for tag [nlp]...
#  Total collected so far: 2305
# Fetching page 109 for tag [nlp]...
#  Total collected so far: 2335
# Fetching page 110 for tag [nlp]...
#  Total collected so far: 2365
# Fetching page 111 for tag [nlp]...
#  Total collected so far: 2395
# Fetching page 112 for tag [nlp]...
#  Total collected so far: 2425
# Fetching page 113 for tag [nlp]...
#  Total collected so far: 2455
# Fetching page 114 for tag [nlp]...
#  Total collected so far: 2485
# Fetching page 115 for tag [nlp]...
#  Total collected so far: 2515
# Fetching page 116 for tag [nlp]...
#  Total collected so far: 2545
# Fetching page 117 for tag [nlp]...
#  Total collected so far: 2575
# Fetching page 118 for tag [nlp]...
#  Total collected so far: 2605
# Fetching page 119 for tag [nlp]...
#  Total collected so far: 2635
# Fetching page 120 for tag [nlp]...
#  Total collected so far: 2665
# Fetching page 121 for tag [nlp]...
#  Total collected so far: 2695
# Fetching page 122 for tag [nlp]...
#  Total collected so far: 2725
# Fetching page 123 for tag [nlp]...
#  Total collected so far: 2755
# Fetching page 124 for tag [nlp]...
#  Total collected so far: 2785
# Fetching page 125 for tag [nlp]...
#  Total collected so far: 2815
# Fetching page 126 for tag [nlp]...
#  Total collected so far: 2845
# Fetching page 127 for tag [nlp]...
#  Total collected so far: 2875
# Fetching page 128 for tag [nlp]...
#  Total collected so far: 2905
# Fetching page 129 for tag [nlp]...
#  Total collected so far: 2935
# Fetching page 130 for tag [nlp]...
#  Total collected so far: 2965
# Fetching page 131 for tag [nlp]...
#  Total collected so far: 2995
# Fetching page 132 for tag [nlp]...
#  Total collected so far: 3025
# Fetching page 133 for tag [nlp]...
#  Total collected so far: 3055
# Fetching page 134 for tag [nlp]...
#  Total collected so far: 3085
# Fetching page 135 for tag [nlp]...
#  Total collected so far: 3115
# Fetching page 136 for tag [nlp]...
#  Total collected so far: 3145
# Fetching page 137 for tag [nlp]...
#  Total collected so far: 3175
# Fetching page 138 for tag [nlp]...
#  Total collected so far: 3205
# Fetching page 139 for tag [nlp]...
#  Total collected so far: 3235
# Fetching page 140 for tag [nlp]...
#  Total collected so far: 3265
# Fetching page 141 for tag [nlp]...
#  Total collected so far: 3295
# Fetching page 142 for tag [nlp]...
#  Total collected so far: 3325
# Fetching page 143 for tag [nlp]...
#  Total collected so far: 3355
# Fetching page 144 for tag [nlp]...
#  Total collected so far: 3385
# Fetching page 145 for tag [nlp]...
#  Total collected so far: 3415
# Fetching page 146 for tag [nlp]...
#  Total collected so far: 3445
# Fetching page 147 for tag [nlp]...
#  Total collected so far: 3475
# Fetching page 148 for tag [nlp]...
#  Total collected so far: 3505
# Fetching page 149 for tag [nlp]...
#  Total collected so far: 3535
# Fetching page 150 for tag [nlp]...
#  Total collected so far: 3565
# Fetching page 151 for tag [nlp]...
#  Total collected so far: 3595
# Fetching page 152 for tag [nlp]...
#  Total collected so far: 3625
# Fetching page 153 for tag [nlp]...
#  Total collected so far: 3655
# Fetching page 154 for tag [nlp]...
#  Total collected so far: 3685
# Fetching page 155 for tag [nlp]...
#  Total collected so far: 3715
# Fetching page 156 for tag [nlp]...
#  Total collected so far: 3745
# Fetching page 157 for tag [nlp]...
#  Total collected so far: 3775
# Fetching page 158 for tag [nlp]...
#  Total collected so far: 3805
# Fetching page 159 for tag [nlp]...
#  Total collected so far: 3835
# Fetching page 160 for tag [nlp]...
#  Total collected so far: 3865
# Fetching page 161 for tag [nlp]...
#  Total collected so far: 3895
# Fetching page 162 for tag [nlp]...
#  Total collected so far: 3925
# Fetching page 163 for tag [nlp]...
#  Total collected so far: 3955
# Fetching page 164 for tag [nlp]...
#  Total collected so far: 3985
# Fetching page 165 for tag [nlp]...
#  Total collected so far: 4015
# Fetching page 166 for tag [nlp]...
#  Total collected so far: 4045
# Fetching page 167 for tag [nlp]...
#  Total collected so far: 4075
# Fetching page 168 for tag [nlp]...
#  Total collected so far: 4105
# Fetching page 169 for tag [nlp]...
#  Total collected so far: 4135
# Fetching page 170 for tag [nlp]...
#  Total collected so far: 4165
# Fetching page 171 for tag [nlp]...
#  Total collected so far: 4195
# Fetching page 172 for tag [nlp]...
#  Total collected so far: 4225
# Fetching page 173 for tag [nlp]...
#  Total collected so far: 4255
# Fetching page 174 for tag [nlp]...
#  Total collected so far: 4285
# Fetching page 175 for tag [nlp]...
#  Total collected so far: 4315
# Fetching page 176 for tag [nlp]...
#  Total collected so far: 4345
# Fetching page 177 for tag [nlp]...
#  Total collected so far: 4375
# Fetching page 178 for tag [nlp]...
#  Total collected so far: 4405
# Fetching page 179 for tag [nlp]...
#  Total collected so far: 4435
# Fetching page 180 for tag [nlp]...
#  Total collected so far: 4465
# Fetching page 181 for tag [nlp]...
#  Total collected so far: 4495
# Fetching page 182 for tag [nlp]...
#  Total collected so far: 4525
# Fetching page 183 for tag [nlp]...
#  Total collected so far: 4555
# Fetching page 184 for tag [nlp]...
#  Total collected so far: 4585
# Fetching page 185 for tag [nlp]...
#  Total collected so far: 4615
# Fetching page 186 for tag [nlp]...
#  Total collected so far: 4645
# Fetching page 187 for tag [nlp]...
#  Total collected so far: 4675
# Fetching page 188 for tag [nlp]...
#  Total collected so far: 4705
# Fetching page 189 for tag [nlp]...
#  Total collected so far: 4735
# Fetching page 190 for tag [nlp]...
#  Total collected so far: 4765
# Fetching page 191 for tag [nlp]...
#  Total collected so far: 4795
# Fetching page 192 for tag [nlp]...
#  Total collected so far: 4825
# Fetching page 193 for tag [nlp]...
#  Total collected so far: 4855
# Fetching page 194 for tag [nlp]...
#  Total collected so far: 4885
# Fetching page 195 for tag [nlp]...
#  Total collected so far: 4915
# Fetching page 196 for tag [nlp]...
#  Total collected so far: 4945
# Fetching page 197 for tag [nlp]...
#  Total collected so far: 4975
# Fetching page 198 for tag [nlp]...
#  Total collected so far: 5000
#  Done! Saved 5000 new Q&A posts to stackoverflow_nlp_posts_part3.json

# %%
import json

# Load and merge three batches of JSON files
with open("stackoverflow_nlp_posts_with_answers.json", "r", encoding="utf-8") as f1, \
     open("stackoverflow_nlp_posts_part2.json", "r", encoding="utf-8") as f2, \
     open("stackoverflow_nlp_posts_part3.json", "r", encoding="utf-8") as f3:
    
    data1 = json.load(f1)
    data2 = json.load(f2)
    data3 = json.load(f3)


combined = data1 + data2 + data3


with open("stackoverflow_nlp_combined_20000.json", "w", encoding="utf-8") as out:
    json.dump(combined, out, indent=2)

print(f" Combined file saved as 'stackoverflow_nlp_combined_20000.json' with {len(combined)} entries")
# Out:
#  Combined file saved as 'stackoverflow_nlp_combined_20000.json' with 22267 entries
